# %% [markdown]
# <a href="https://colab.research.google.com/github/WilsonGLan/Platzi/blob/main/4_Dise%C3%B1ando_mapas_Curvas_de_nivel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Dependencias

# %%
from matplotlib import cm # Para manejar colores
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gráfica en 3 dimensiones

# %% [markdown]
# La función **`numpy.meshgrid`** devuelve una lista de matrices de coordenadas a partir de vectores de coordenadas. Acepta como entrada las coordenadas que definen el segmento del hiperplano (puede tratarse de dos dimensiones o de cualquier otro número de ellas) y devuelve arrays con las coordenadas de dichos puntos:

# %%
coord_x = [0,1,2]
coord_y = [0,1,2]
x, y = np.meshgrid(coord_x, coord_y)
print('Lo que tiene x:\n', x)
print('Lo que tiene y:\n', y)
# Out:
# Lo que tiene x:
#  [[0 1 2]
#  [0 1 2]
#  [0 1 2]]
# Lo que tiene y:
#  [[0 0 0]
#  [1 1 1]
#  [2 2 2]]

# %% [markdown]
# Ref: https://interactivechaos.com/es/manual/tutorial-de-numpy/la-funcion-meshgrid

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})


res = 100

X = np.linspace(-4, 4, res)
Y = np.linspace(-4, 4, res)

X, Y = np.meshgrid(X, Y)

Z = np.sin(X) + 2*np.sin(Y) 

# Gráficar la superficie
surf = ax.plot_surface(X, Y, Z, cmap=cm.cool,
                       linewidth=0, antialiased=False)

fig.colorbar(surf)

# %%
def f(x,y):
  return np.sin(x) + 2 * np.cos(y)

res = 100
x= np.linspace(-4,4, num=res)
y= np.linspace(-4,4, num=res)

x, y = np.meshgrid(x,y)
z = f(x,y)

# Graficar

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(x,y,z)

# %%
def f(x,y):
  return np.sin(x) + 2 * np.cos(y)

res = 100
x= np.linspace(-4,4, num=res)
y= np.linspace(-4,4, num=res)

x, y = np.meshgrid(x,y)
z = f(x,y)

# Graficar

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(x,y,z, cmap = cm.cool)
fig.colorbar(surf)

# %% [markdown]
# ### Curvas de nivel

# %%
fig2, ax2 = plt.subplots()
level_map = np.linspace(np.min(z),np.max(z), num=res)

cp = ax2.contour(x,y,z,levels= level_map, cmap = cm.cool)
fig2.colorbar(cp)

# %%
fig2, ax2 = plt.subplots()
level_map = np.linspace(np.min(z),np.max(z), num=res)

cp = ax2.contourf(x,y,z,levels= level_map, cmap = cm.cool)
fig2.colorbar(cp)
